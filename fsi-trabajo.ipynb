# %%
import tensorflow
tensorflow.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
pil_im = Image.open('/kaggle/input/vegetablesdataset/Vegetable Images/test/Tomato/1011.jpg', 'r')


imshow(np.asarray(pil_im))

# %%
from tensorflow.keras import backend as K
from time import time

# DATA SOURCE --------------------------------------------------

train_data_dir = '/kaggle/input/vegetablesdataset/Vegetable Images/train'
validation_data_dir = '/kaggle/input/vegetablesdataset/Vegetable Images/validation'
test_data_dir = '/kaggle/input/vegetablesdataset/Vegetable Images/test'
image_size = (223, 223)
batch_size = 32

# %%
train_ds = tensorflow.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    #validation_split=0.2,
    #subset="training",
    #seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)

validation_ds = tensorflow.keras.preprocessing.image_dataset_from_directory(
    validation_data_dir,
    #validation_split=0.2,
    #subset="validation",
    #seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)

test_ds = tensorflow.keras.preprocessing.image_dataset_from_directory(
    test_data_dir,
    #validation_split=0.2,
    #subset="validation",
    #seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)

train_ds = train_ds.prefetch(buffer_size=32)
validation_ds = validation_ds.prefetch(buffer_size=32)
test_ds = test_ds.prefetch(buffer_size=32)
# Out:
# Found 15000 files belonging to 15 classes.
# Found 3000 files belonging to 15 classes.
# Found 3000 files belonging to 15 classes.

# %% [markdown]
# # **Image Augmentation**

# %%
#from tensorflow.keras.preprocessing.image import ImageDataGenerator

#train_datagen = ImageDataGenerator(
#        rescale=1./255,
#        rotation_range=15,
#        zoom_range=0.1
#)

#validation_datagen = ImageDataGenerator(
#        rescale=1./255
#)


#train_ds_augmentation = train_datagen.flow_from_directory(
#    train_data_dir,
#    #validation_split=0.2,
#    #subset="training",
#    #seed=1337,
#    target_size=image_size,
#    batch_size=batch_size,
#    class_mode='categorical'
#)

#validation_ds_augmentation = validation_datagen.flow_from_directory(
#    validation_data_dir,
#    #validation_split=0.2,
#    #subset="validation",
#    #seed=1337,
#    target_size=image_size,
#    batch_size=batch_size,
#    class_mode='categorical'
#)

# %% [markdown]
# # **The Model**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Rescaling                    

# MODEL --------------------------------------------------

model = Sequential()
# Capa de reescalado para normalizar los valores de píxeles
model.add(Rescaling(scale=(1./127.5),offset=-1, input_shape=(223, 223, 3)))  

#model.add(Conv2D(16, kernel_size=(3, 3), activation='relu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))

# Capas convolucionales
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))# Capa de Dropout para prevenir el sobreajuste

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5)) # Capa de Dropout para prevenir el sobreajuste

# Capa de aplanado para convertir la salida en un vector unidimensional
model.add(Flatten())
# Capa fully connected (completamente conectada) con activación ReLU y Dropout
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5)) # Capa de Dropout para prevenir el sobreajuste

#Capa con activacion softmax para la clasificacion multiclase
model.add(Dense(15, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 223, 223, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 221, 221, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 108, 108, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               22151424
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                3855
# =================================================================
# Total params: 22,248,527
# Trainable params: 22,248,527
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tensorflow.keras.losses.categorical_crossentropy,
              optimizer=tensorflow.keras.optimizers.Adam(1e-3),
              metrics=['accuracy'])

# %%
# TRAINING --------------------------------------------------
from tensorflow.keras.callbacks import EarlyStopping
import time
start_time = time.time()

epochs = 200

es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=10, restore_best_weights=True)

history = model.fit(
          train_ds,
          epochs=epochs,
          validation_data = validation_ds,
          callbacks = [es]
)

end_time = time.time()
elapsed_time = end_time - start_time
print(f"\nTiempo total de entrenamiento: {round((elapsed_time / 60),1)} minutos")
# Out:
# Epoch 1/200
# 469/469 [==============================] - 47s 78ms/step - loss: 1.3729 - accuracy: 0.5533 - val_loss: 0.6815 - val_accuracy: 0.7977
# Epoch 2/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.5999 - accuracy: 0.8089 - val_loss: 0.3246 - val_accuracy: 0.9070
# Epoch 3/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.4068 - accuracy: 0.8737 - val_loss: 0.2323 - val_accuracy: 0.9283
# Epoch 4/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.2871 - accuracy: 0.9107 - val_loss: 0.1607 - val_accuracy: 0.9557
# Epoch 5/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.2211 - accuracy: 0.9308 - val_loss: 0.1394 - val_accuracy: 0.9620
# Epoch 6/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.1851 - accuracy: 0.9420 - val_loss: 0.1480 - val_accuracy: 0.9613
# Epoch 7/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.1665 - accuracy: 0.9483 - val_loss: 0.1276 - val_accuracy: 0.9637
# Epoch 8/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.1422 - accuracy: 0.9563 - val_loss: 0.1018 - val_accuracy: 0.9760
# Epoch 9/200
# 469/469 [==============================] - 26s 56ms/step - loss: 0.1383 - accuracy: 0.9581 - val_loss: 0.1459 - val_accuracy: 0.9610
# Epoch 10/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.1109 - accuracy: 0.9647 - val_loss: 0.1366 - val_accuracy: 0.9620
# Epoch 11/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.1052 - accuracy: 0.9671 - val_loss: 0.1146 - val_accuracy: 0.9717
# Epoch 12/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.1077 - accuracy: 0.9667 - val_loss: 0.1041 - val_accuracy: 0.9747
# Epoch 13/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0776 - accuracy: 0.9743 - val_loss: 0.1826 - val_accuracy: 0.9600
# Epoch 14/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0971 - accuracy: 0.9701 - val_loss: 0.0781 - val_accuracy: 0.9787
# Epoch 15/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0826 - accuracy: 0.9759 - val_loss: 0.0980 - val_accuracy: 0.9753
# Epoch 16/200
# 469/469 [==============================] - 26s 54ms/step - loss: 0.0819 - accuracy: 0.9752 - val_loss: 0.1260 - val_accuracy: 0.9753
# Epoch 17/200
# 469/469 [==============================] - 26s 54ms/step - loss: 0.0811 - accuracy: 0.9752 - val_loss: 0.1115 - val_accuracy: 0.9780
# Epoch 18/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.1010 - accuracy: 0.9739 - val_loss: 0.0964 - val_accuracy: 0.9807
# Epoch 19/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0656 - accuracy: 0.9798 - val_loss: 0.2289 - val_accuracy: 0.9590
# Epoch 20/200
# 469/469 [==============================] - 26s 56ms/step - loss: 0.0627 - accuracy: 0.9809 - val_loss: 0.1295 - val_accuracy: 0.9730
# Epoch 21/200
# 469/469 [==============================] - 26s 54ms/step - loss: 0.0719 - accuracy: 0.9787 - val_loss: 0.0997 - val_accuracy: 0.9797
# Epoch 22/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0720 - accuracy: 0.9799 - val_loss: 0.1242 - val_accuracy: 0.9747
# Epoch 23/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0516 - accuracy: 0.9842 - val_loss: 0.0882 - val_accuracy: 0.9820
# Epoch 24/200
# 469/469 [==============================] - 26s 54ms/step - loss: 0.0483 - accuracy: 0.9857 - val_loss: 0.2172 - val_accuracy: 0.9560
# Epoch 25/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0628 - accuracy: 0.9825 - val_loss: 0.0929 - val_accuracy: 0.9783
# Epoch 26/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0577 - accuracy: 0.9829 - val_loss: 0.0983 - val_accuracy: 0.9800
# Epoch 27/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0627 - accuracy: 0.9827 - val_loss: 0.1478 - val_accuracy: 0.9717
# Epoch 28/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0511 - accuracy: 0.9849 - val_loss: 0.1152 - val_accuracy: 0.9760
# Epoch 29/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0575 - accuracy: 0.9841 - val_loss: 0.1605 - val_accuracy: 0.9750
# Epoch 30/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0522 - accuracy: 0.9853 - val_loss: 0.0912 - val_accuracy: 0.9813
# Epoch 31/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0649 - accuracy: 0.9828 - val_loss: 0.1241 - val_accuracy: 0.9750
# Epoch 32/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0731 - accuracy: 0.9823 - val_loss: 0.1253 - val_accuracy: 0.9763
# Epoch 33/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0287 - accuracy: 0.9914 - val_loss: 0.0846 - val_accuracy: 0.9840
# Epoch 34/200
# 469/469 [==============================] - 26s 54ms/step - loss: 0.0589 - accuracy: 0.9839 - val_loss: 0.0882 - val_accuracy: 0.9837
# Epoch 35/200
# 469/469 [==============================] - 26s 54ms/step - loss: 0.0493 - accuracy: 0.9851 - val_loss: 0.1299 - val_accuracy: 0.9773
# Epoch 36/200
# 469/469 [==============================] - 26s 56ms/step - loss: 0.0411 - accuracy: 0.9882 - val_loss: 0.1105 - val_accuracy: 0.9803
# Epoch 37/200
# 469/469 [==============================] - 26s 54ms/step - loss: 0.0861 - accuracy: 0.9798 - val_loss: 0.1166 - val_accuracy: 0.9803
# Epoch 38/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0423 - accuracy: 0.9875 - val_loss: 0.1078 - val_accuracy: 0.9840
# Epoch 39/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0286 - accuracy: 0.9917 - val_loss: 0.1650 - val_accuracy: 0.9763
# Epoch 40/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0731 - accuracy: 0.9835 - val_loss: 0.1453 - val_accuracy: 0.9747
# Epoch 41/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0510 - accuracy: 0.9861 - val_loss: 0.0964 - val_accuracy: 0.9830
# Epoch 42/200
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0393 - accuracy: 0.9889 - val_loss: 0.1166 - val_accuracy: 0.9803
# Epoch 43/200
# 469/469 [==============================] - 27s 56ms/step - loss: 0.0430 - accuracy: 0.9889 - val_loss: 0.1202 - val_accuracy: 0.9823
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
#
# Tiempo total de entrenamiento: 19.0 minutos

# %%
# SAVING --------------------------------------------------

model.save("mimodelo.h5")

# %% [markdown]
# #  **Evaluación de resultados**

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

print("#################################")
print("")
print("Explicacion de las metricas usadas:")
print("1.- Precision: proporción de instancias clasificadas como positivas que son realmente positivas")
print("2.- Recall: proporción de instancias positivas que fueron correctamente identificadas por el modelo")
print("3.- F1-score: media armónica de la precisión y el recall")
print("4.- Support: número de instancias reales en cada clase en el conjunto de prueba")
print("5,- Accuracy: proporción de instancias clasificadas correctamente, independientemente de la clase")
print("6.- Macro AVG: promedio no ponderado de las métricas (precision, recall, F1-score) para todas las clases")
print("7.- Weighted AVG: promedio ponderado de las métricas para todas las clases, donde cada clase se pondera según su soporte (número de instancias)")
print("")
print("#################################")

results = np.concatenate([(y, model.predict(x=x)) for x, y in validation_ds], axis=1)

labels = np.argmax(results[0], axis=1)
predictions = np.argmax(results[1], axis=1)

cf_matrix = confusion_matrix(labels, predictions)

sns.heatmap(cf_matrix, annot=True, fmt="d", cmap="Blues")

#disp = ConfusionMatrixDisplay(confusion_matrix=cf_matrix)
#disp.plot()

print(classification_report(labels, predictions, digits = 4))
# Out:
# #################################
#
# Explicacion de las metricas usadas:
# 1.- Precision: proporción de instancias clasificadas como positivas que son realmente positivas
# 2.- Recall: proporción de instancias positivas que fueron correctamente identificadas por el modelo
# 3.- F1-score: media armónica de la precisión y el recall
# 4.- Support: número de instancias reales en cada clase en el conjunto de prueba
# 5,- Accuracy: proporción de instancias clasificadas correctamente, independientemente de la clase
# 6.- Macro AVG: promedio no ponderado de las métricas (precision, recall, F1-score) para todas las clases
# 7.- Weighted AVG: promedio ponderado de las métricas para todas las clases, donde cada clase se pondera según su soporte (número de instancias)
#
# #################################
#               precision    recall  f1-score   support
#
#            0     0.9706    0.9900    0.9802       200
#            1     0.9852    1.0000    0.9926       200
#            2     0.9752    0.9850    0.9801       200
#            3     0.9847    0.9650    0.9747       200
#            4     0.9851    0.9900    0.9875       200
#            5     0.9849    0.9800    0.9825       200
#            6     0.9615    1.0000    0.9804       200
#            7     0.9950    1.0000    0.9975       200
#            8     0.9706    0.9900    0.9802       200
#            9     1.0000    0.9900    0.9950       200
#           10     0.9949    0.9750    0.9848       200
#           11     1.0000    0.9850    0.9924       200
#           12     0.9895    0.9450    0.9668       200
#           13     0.9852    1.0000    0.9926       200
#           14     0.9797    0.9650    0.9723       200
#
#     accuracy                         0.9840      3000
#    macro avg     0.9841    0.9840    0.9840      3000
# weighted avg     0.9841    0.9840    0.9840      3000

# %%
from matplotlib import pyplot as plt 


plt.plot(history.history['accuracy'], label='accuracy', color = 'Orange')

plt.plot(history.history['loss'], label='loss',color = 'Green')

plt.title('Entrenamiento Distincion de verduras')

plt.xlabel('Épocas')
plt.ylabel('Exactitud')
plt.legend(loc="upper right")

plt.show()


plt.plot(history.history['val_accuracy'], label='validation accuracy',color = 'Blue')
plt.plot(history.history['loss'], label='loss', color = 'Green')

plt.title('Entrenamiento Distincion de verduras')

plt.xlabel('Épocas')
plt.ylabel('Exactitud')
plt.legend(loc="upper right")

plt.show()

# %%
# Evaluar el modelo
def generatePlot(history):
    # Extracción de datos
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    # Creación del gráfico de accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b', label='Training')
    plt.plot(epochs, val_acc, 'r', label='Validation')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Épocas')
    plt.ylabel('Accuracy')
    plt.legend()

    # Creación del gráfico de loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b', label='Training')
    plt.plot(epochs, val_loss, 'r', label='Validation')
    plt.title('Training and Validation Loss')
    plt.xlabel('Épocas')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

generatePlot(history)

# %%
# PRODUCTION ----------------------------------------------

from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image
import tensorflow.keras

# LOADING --------------------------------------------------
#model = tensorflow.keras.models.load_model("mimodelo.h5")

etiquetas=['Bean','Bitter_Gourd', 'Bottle_Gourd','Brinjal', 'Broccoli', 'Cabbage','Capsium','Carrot','Cauliflower','Cucumber','Papaya','Potato','Pumpkin', 'Radish','Tomato']
# %matplotlib inline

pil_im = Image.open('/kaggle/input/vegetablesdataset/Vegetable Images/test/Carrot/1005.jpg', 'r')
im = np.asarray(pil_im.resize((223, 223)))
imshow(im)
print(im.shape) # La imagen es un array de dimensión: 150x150x3

# El método `predict` hace la predicción de un lote de entradas, no solo una. 
# En el caso de que tengamos solo una entrada deberemos añadirle una dimensión más 
# al array numpy para que la entrada tenga la dimensión: 1x150x150x3

im = im.reshape(1,223,223,3)


print('El vector de salida obtenido: ', model.predict(im))
print('La etiqueta de salida predicha es ', np.argmax(model.predict(im)))
print('Ahora dicho con texto: La etiqueta de salida predicha es ', etiquetas[np.argmax(model.predict(im))])
# Out:
# (223, 223, 3)
# El vector de salida obtenido:  [[2.4588831e-31 1.3214009e-26 2.6654880e-33 6.4346170e-34 1.0404306e-30
#   8.9853554e-35 8.6707831e-20 1.0000000e+00 2.5489599e-35 2.9711598e-35
#   2.8516212e-34 2.4777759e-20 1.9315395e-23 8.9380007e-29 2.2131067e-19]]
# La etiqueta de salida predicha es  7
# Ahora dicho con texto: La etiqueta de salida predicha es  Carrot

# %%
# PRODUCTION ----------------------------------------------

#from matplotlib.pyplot import imshow
import numpy as np
#from PIL import Image
import tensorflow.keras

# SAVING --------------------------------------------------
#model.save_model("mimodelo.h5")


# LOADING --------------------------------------------------
#model = tensorflow.keras.models.load_model("mimodelo.h5")

etiquetas=['Bean','Bitter_Gourd', 'Bottle_Gourd','Brinjal', 'Broccoli', 'Cabbage','Capsium','Carrot','Cauliflower','Cucumber','Papaya','Potato','Pumpkin', 'Radish','Tomato']
# %matplotlib inline
errores_totales = 0
aciertos = 0
print("ETIQUETA PREDICHA -> ETIQUETA REAL")
for minilote in test_ds:
    prediccion_minilote = model.predict(minilote[0].numpy())
    etiqueta_real_minilote = minilote[1].numpy()
    for y_predicha, y_real in zip(np.round(prediccion_minilote,3), etiqueta_real_minilote):
        if np.argmax(y_predicha) == np.argmax(y_real):
            print(etiquetas[np.argmax(y_predicha)], "->", etiquetas[np.argmax(y_real)])
            aciertos += 1
        else:
            print(etiquetas[np.argmax(y_predicha)], "->", etiquetas[np.argmax(y_real)], "✘")
            errores_totales += 1
print(f"\nTotal de errores: {errores_totales} ")
print(f"\nTotal de aciertos: {aciertos} ")
# Out:
# ETIQUETA PREDICHA -> ETIQUETA REAL
# Radish -> Radish
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Bean -> Broccoli ✘
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Potato -> Potato
# Pumpkin -> Pumpkin
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Bean -> Bean
# Papaya -> Papaya
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Carrot -> Carrot
# Potato -> Potato
# Bean -> Bean
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Carrot -> Carrot
# Brinjal -> Brinjal
# Tomato -> Tomato
# Radish -> Radish
# Potato -> Potato
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Tomato -> Tomato
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Bean -> Bean
# Cauliflower -> Cauliflower
# Radish -> Radish
# Cucumber -> Cucumber
# Potato -> Potato
# Bean -> Bean
# Radish -> Radish
# Carrot -> Carrot
# Brinjal -> Brinjal
# Radish -> Radish
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Radish -> Radish
# Carrot -> Carrot
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Brinjal -> Brinjal
# Capsium -> Capsium
# Tomato -> Tomato
# Radish -> Radish
# Broccoli -> Broccoli
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Radish -> Radish
# Capsium -> Capsium
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Papaya -> Papaya
# Carrot -> Carrot
# Radish -> Radish
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Papaya -> Papaya
# Cabbage -> Cabbage
# Bean -> Bean
# Capsium -> Capsium
# Broccoli -> Broccoli
# Papaya -> Papaya
# Carrot -> Carrot
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Radish -> Radish
# Brinjal -> Brinjal
# Cauliflower -> Cauliflower
# Bean -> Bean
# Capsium -> Capsium
# Carrot -> Carrot
# Cucumber -> Cucumber
# Carrot -> Carrot
# Bean -> Bean
# Capsium -> Capsium
# Capsium -> Bean ✘
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Bean -> Bean
# Cauliflower -> Cauliflower
# Cucumber -> Cucumber
# Cucumber -> Cucumber
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Brinjal -> Brinjal
# Potato -> Potato
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Radish -> Radish
# Papaya -> Papaya
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Papaya -> Papaya
# Cucumber -> Cucumber
# Carrot -> Carrot
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Capsium -> Capsium
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Capsium -> Capsium
# Broccoli -> Broccoli
# Pumpkin -> Pumpkin
# Cabbage -> Cabbage
# Potato -> Potato
# Pumpkin -> Pumpkin
# Cabbage -> Cauliflower ✘
# Potato -> Potato
# Bean -> Bean
# Cabbage -> Cabbage
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Radish -> Radish
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Carrot -> Carrot
# Bean -> Bean
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Capsium -> Capsium
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Brinjal -> Brinjal
# Potato -> Potato
# Bottle_Gourd -> Bottle_Gourd
# Bean -> Bean
# Radish -> Radish
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Tomato -> Tomato
# Carrot -> Carrot
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Cabbage -> Cabbage
# Tomato -> Tomato
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Papaya -> Papaya
# Radish -> Radish
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Papaya -> Papaya
# Bottle_Gourd -> Bottle_Gourd
# Carrot -> Carrot
# Capsium -> Capsium
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Capsium -> Capsium
# Potato -> Potato
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Pumpkin -> Pumpkin
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Carrot -> Carrot
# Potato -> Potato
# Potato -> Potato
# Cabbage -> Cabbage
# Bean -> Radish ✘
# Papaya -> Papaya
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Radish -> Radish
# Bean -> Bean
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Potato -> Potato
# Tomato -> Tomato
# Tomato -> Tomato
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Papaya -> Papaya
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Bean -> Bean
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Cucumber -> Cucumber
# Radish -> Potato ✘
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Tomato -> Tomato
# Carrot -> Carrot
# Carrot -> Carrot
# Carrot -> Carrot
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Brinjal -> Brinjal
# Capsium -> Capsium
# Bean -> Bean
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Bean -> Bean
# Potato -> Potato
# Potato -> Potato
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Radish -> Radish
# Brinjal -> Brinjal
# Capsium -> Capsium
# Broccoli -> Broccoli
# Papaya -> Papaya
# Potato -> Potato
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Tomato -> Tomato
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Carrot -> Carrot
# Bottle_Gourd -> Brinjal ✘
# Cucumber -> Cucumber
# Bean -> Bean
# Bean -> Bean
# Tomato -> Tomato
# Broccoli -> Broccoli
# Radish -> Radish
# Cabbage -> Cabbage
# Bean -> Bean
# Radish -> Radish
# Bean -> Bean
# Bean -> Bean
# Bitter_Gourd -> Bitter_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Cabbage -> Cucumber ✘
# Broccoli -> Broccoli
# Radish -> Radish
# Radish -> Radish
# Pumpkin -> Pumpkin
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Bean -> Bean
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Cucumber -> Cucumber
# Bean -> Bean
# Tomato -> Tomato
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Potato -> Potato
# Cucumber -> Cucumber
# Radish -> Radish
# Capsium -> Capsium
# Cauliflower -> Cabbage ✘
# Carrot -> Carrot
# Broccoli -> Broccoli
# Carrot -> Carrot
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Potato -> Potato
# Bean -> Bean
# Broccoli -> Broccoli
# Potato -> Potato
# Brinjal -> Brinjal
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Cauliflower -> Cauliflower
# Broccoli -> Broccoli
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Potato -> Potato
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Tomato -> Tomato
# Radish -> Radish
# Tomato -> Tomato
# Bean -> Bean
# Potato -> Potato
# Bean -> Bean
# Tomato -> Tomato
# Potato -> Potato
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Tomato -> Tomato
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Carrot -> Carrot
# Papaya -> Papaya
# Cucumber -> Cucumber
# Tomato -> Tomato
# Papaya -> Papaya
# Radish -> Radish
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Tomato -> Tomato
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Radish -> Radish
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Pumpkin -> Pumpkin
# Potato -> Potato
# Papaya -> Papaya
# Potato -> Potato
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Bean -> Bean
# Carrot -> Carrot
# Brinjal -> Brinjal
# Potato -> Potato
# Radish -> Radish
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Papaya -> Papaya
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Radish -> Radish
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Capsium -> Capsium
# Papaya -> Papaya
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Potato -> Potato
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Papaya -> Papaya
# Cabbage -> Cabbage
# Capsium -> Capsium
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Broccoli -> Broccoli
# Potato -> Potato
# Carrot -> Carrot
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Cucumber -> Cucumber
# Radish -> Tomato ✘
# Radish -> Radish
# Cabbage -> Cabbage
# Broccoli -> Broccoli
# Radish -> Radish
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Bean -> Bean
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Carrot -> Carrot
# Tomato -> Tomato
# Radish -> Radish
# Cauliflower -> Cauliflower
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Potato -> Potato
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Broccoli -> Broccoli
# Capsium -> Capsium
# Cabbage -> Broccoli ✘
# Potato -> Potato
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Papaya -> Papaya
# Potato -> Potato
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Bean -> Bean
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Papaya -> Papaya
# Pumpkin -> Tomato ✘
# Bitter_Gourd -> Bitter_Gourd
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Radish -> Radish
# Bean -> Bean
# Tomato -> Tomato
# Brinjal -> Brinjal
# Radish -> Radish
# Papaya -> Papaya
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Potato -> Potato
# Cucumber -> Cucumber
# Tomato -> Tomato
# Radish -> Radish
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Bean -> Bean
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Bean -> Bean
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Potato -> Potato
# Bitter_Gourd -> Pumpkin ✘
# Cucumber -> Cucumber
# Potato -> Potato
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Carrot -> Carrot
# Cauliflower -> Cauliflower
# Cucumber -> Cucumber
# Bean -> Bean
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Bean -> Bean
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Capsium -> Capsium
# Carrot -> Carrot
# Papaya -> Papaya
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Potato -> Potato
# Papaya -> Papaya
# Bean -> Bean
# Cabbage -> Cabbage
# Capsium -> Capsium
# Tomato -> Tomato
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Cabbage -> Cabbage
# Pumpkin -> Pumpkin
# Bean -> Bean
# Carrot -> Carrot
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Carrot -> Carrot
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Tomato -> Tomato
# Potato -> Potato
# Radish -> Radish
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Cabbage -> Cabbage
# Bean -> Bean
# Brinjal -> Brinjal
# Carrot -> Carrot
# Carrot -> Carrot
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Papaya -> Papaya
# Cabbage -> Cabbage
# Pumpkin -> Pumpkin
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Potato -> Potato
# Bean -> Bean
# Capsium -> Capsium
# Brinjal -> Brinjal
# Papaya -> Papaya
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Cucumber -> Cucumber
# Bean -> Bean
# Tomato -> Tomato
# Tomato -> Tomato
# Potato -> Potato
# Cabbage -> Cabbage
# Cabbage -> Cabbage
# Potato -> Potato
# Tomato -> Tomato
# Carrot -> Carrot
# Potato -> Potato
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Cucumber -> Cucumber
# Tomato -> Tomato
# Radish -> Radish
# Bean -> Bean
# Potato -> Potato
# Papaya -> Papaya
# Broccoli -> Broccoli
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Papaya -> Papaya
# Broccoli -> Broccoli
# Capsium -> Capsium
# Bean -> Bean
# Bitter_Gourd -> Bitter_Gourd
# Bean -> Bean
# Brinjal -> Brinjal
# Capsium -> Capsium
# Carrot -> Carrot
# Pumpkin -> Cauliflower ✘
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Carrot -> Carrot
# Tomato -> Tomato
# Cucumber -> Cucumber
# Carrot -> Carrot
# Papaya -> Papaya
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Cabbage -> Cabbage
# Broccoli -> Broccoli
# Carrot -> Carrot
# Carrot -> Carrot
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Radish -> Radish
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Radish -> Radish
# Capsium -> Capsium
# Cauliflower -> Cauliflower
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Tomato -> Tomato
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Bean -> Bean
# Papaya -> Papaya
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Carrot -> Carrot
# Brinjal -> Brinjal
# Bean -> Bean
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Bean -> Bean
# Tomato -> Tomato
# Capsium -> Capsium
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Potato -> Potato
# Broccoli -> Broccoli
# Tomato -> Tomato
# Tomato -> Tomato
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Pumpkin -> Pumpkin
# Potato -> Potato
# Broccoli -> Broccoli
# Capsium -> Capsium
# Broccoli -> Broccoli
# Radish -> Radish
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Radish -> Radish
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Radish -> Radish
# Bean -> Bean
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Bean -> Bean
# Carrot -> Carrot
# Potato -> Potato
# Radish -> Potato ✘
# Tomato -> Tomato
# Carrot -> Carrot
# Carrot -> Carrot
# Papaya -> Papaya
# Tomato -> Tomato
# Radish -> Radish
# Carrot -> Carrot
# Brinjal -> Brinjal
# Potato -> Potato
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Potato -> Potato
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Bean -> Bean
# Tomato -> Tomato
# Bean -> Bean
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Bean -> Bean
# Bean -> Bean
# Cauliflower -> Cauliflower
# Cucumber -> Cucumber
# Cucumber -> Cucumber
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Papaya -> Papaya
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Cauliflower -> Cauliflower
# Cabbage -> Cabbage
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Potato -> Potato
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Bean -> Bean
# Papaya -> Papaya
# Capsium -> Capsium
# Tomato -> Tomato
# Potato -> Potato
# Broccoli -> Broccoli
# Capsium -> Capsium
# Broccoli -> Broccoli
# Radish -> Radish
# Radish -> Radish
# Cabbage -> Cabbage
# Broccoli -> Broccoli
# Papaya -> Papaya
# Cabbage -> Cabbage
# Bean -> Bean
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Bean -> Bean
# Papaya -> Papaya
# Carrot -> Carrot
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Capsium -> Capsium
# Radish -> Radish
# Pumpkin -> Pumpkin
# Cauliflower -> Cauliflower
# Potato -> Potato
# Potato -> Potato
# Cucumber -> Cucumber
# Capsium -> Capsium
# Capsium -> Capsium
# Cucumber -> Cucumber
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Carrot -> Carrot
# Cauliflower -> Cauliflower
# Radish -> Radish
# Capsium -> Capsium
# Papaya -> Papaya
# Bottle_Gourd -> Bottle_Gourd
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Radish -> Radish
# Radish -> Radish
# Pumpkin -> Pumpkin
# Cabbage -> Cabbage
# Papaya -> Papaya
# Capsium -> Capsium
# Capsium -> Capsium
# Bean -> Bean
# Carrot -> Carrot
# Brinjal -> Brinjal
# Cauliflower -> Cauliflower
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Tomato -> Tomato
# Tomato -> Tomato
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Capsium -> Capsium
# Broccoli -> Broccoli
# Capsium -> Capsium
# Cabbage -> Cabbage
# Tomato -> Tomato
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Tomato -> Tomato
# Cauliflower -> Cauliflower
# Potato -> Potato
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Cauliflower -> Cabbage ✘
# Cabbage -> Cabbage
# Papaya -> Papaya
# Tomato -> Tomato
# Bean -> Bean
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Carrot -> Carrot
# Papaya -> Papaya
# Cabbage -> Cabbage
# Broccoli -> Broccoli
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Carrot -> Carrot
# Papaya -> Papaya
# Tomato -> Tomato
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Cauliflower -> Cauliflower
# Radish -> Radish
# Broccoli -> Broccoli
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Potato -> Potato
# Radish -> Radish
# Capsium -> Capsium
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Cabbage -> Cabbage
# Papaya -> Papaya
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Bean -> Bean
# Potato -> Potato
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Carrot -> Carrot
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Carrot -> Carrot
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Bean -> Bean
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Bean -> Bean
# Bean -> Bean
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Bean -> Bean
# Brinjal -> Brinjal
# Bean -> Bean
# Cauliflower -> Cauliflower
# Cucumber -> Cucumber
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Capsium -> Capsium
# Carrot -> Carrot
# Papaya -> Papaya
# Carrot -> Carrot
# Carrot -> Carrot
# Cabbage -> Cabbage
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Bean -> Bean
# Potato -> Potato
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Tomato -> Tomato
# Bean -> Bean
# Pumpkin -> Pumpkin
# Potato -> Potato
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Bean -> Bean
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Broccoli -> Broccoli
# Radish -> Radish
# Tomato -> Tomato
# Cucumber -> Cucumber
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Pumpkin -> Pumpkin
# Radish -> Radish
# Cucumber -> Cucumber
# Radish -> Radish
# Cabbage -> Cabbage
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Radish -> Radish
# Papaya -> Papaya
# Tomato -> Tomato
# Carrot -> Carrot
# Tomato -> Tomato
# Bean -> Bean
# Broccoli -> Broccoli
# Papaya -> Papaya
# Cabbage -> Cabbage
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Bean -> Bean
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Carrot -> Carrot
# Carrot -> Carrot
# Broccoli -> Broccoli
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Tomato -> Tomato
# Papaya -> Papaya
# Brinjal -> Brinjal
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Cucumber -> Cucumber
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Radish -> Radish
# Brinjal -> Brinjal
# Potato -> Potato
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Papaya -> Papaya
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Capsium -> Capsium
# Capsium -> Capsium
# Cauliflower -> Cauliflower
# Pumpkin -> Pumpkin
# Potato -> Potato
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Papaya -> Papaya
# Bean -> Bean
# Brinjal -> Brinjal
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Cucumber -> Cucumber
# Potato -> Potato
# Cucumber -> Cucumber
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Broccoli -> Broccoli
# Capsium -> Capsium
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Potato -> Potato
# Radish -> Radish
# Potato -> Potato
# Cauliflower -> Cauliflower
# Radish -> Potato ✘
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Carrot -> Carrot
# Cauliflower -> Cauliflower
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Radish -> Radish
# Brinjal -> Brinjal
# Cucumber -> Cucumber
# Capsium -> Capsium
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Radish -> Radish
# Radish -> Radish
# Bean -> Bean
# Broccoli -> Broccoli
# Bean -> Bean
# Radish -> Radish
# Tomato -> Tomato
# Tomato -> Tomato
# Radish -> Tomato ✘
# Radish -> Radish
# Radish -> Radish
# Potato -> Potato
# Cabbage -> Cabbage
# Cabbage -> Cabbage
# Cabbage -> Cabbage
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Bean -> Bean
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Potato -> Potato
# Papaya -> Papaya
# Capsium -> Capsium
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Bean -> Bean
# Bean -> Bean
# Papaya -> Papaya
# Potato -> Potato
# Carrot -> Carrot
# Papaya -> Papaya
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Capsium -> Capsium
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Carrot -> Carrot
# Radish -> Tomato ✘
# Bitter_Gourd -> Bitter_Gourd
# Papaya -> Papaya
# Carrot -> Carrot
# Radish -> Radish
# Potato -> Potato
# Capsium -> Capsium
# Carrot -> Carrot
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Papaya -> Papaya
# Radish -> Radish
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Cabbage -> Cabbage
# Carrot -> Carrot
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Bean -> Bean
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Papaya -> Papaya
# Carrot -> Carrot
# Broccoli -> Broccoli
# Capsium -> Capsium
# Broccoli -> Broccoli
# Carrot -> Carrot
# Bottle_Gourd -> Bottle_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Carrot -> Carrot
# Tomato -> Tomato
# Bean -> Bean
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Radish -> Radish
# Tomato -> Tomato
# Bean -> Bean
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Radish -> Tomato ✘
# Bean -> Bean
# Potato -> Potato
# Capsium -> Capsium
# Papaya -> Papaya
# Brinjal -> Brinjal
# Capsium -> Capsium
# Cucumber -> Cucumber
# Papaya -> Papaya
# Bean -> Bean
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Tomato -> Tomato
# Cucumber -> Cucumber
# Papaya -> Papaya
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Carrot -> Carrot
# Brinjal -> Brinjal
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Carrot -> Carrot
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Pumpkin -> Pumpkin
# Bean -> Bean
# Radish -> Radish
# Capsium -> Capsium
# Potato -> Potato
# Broccoli -> Broccoli
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Radish -> Radish
# Bean -> Bean
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Bean -> Bean
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Tomato -> Tomato
# Cabbage -> Cabbage
# Papaya -> Papaya
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Potato -> Potato
# Cabbage -> Cabbage
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Broccoli -> Broccoli
# Potato -> Potato
# Cauliflower -> Cabbage ✘
# Cucumber -> Cucumber
# Papaya -> Papaya
# Papaya -> Papaya
# Bean -> Bean
# Bean -> Cucumber ✘
# Broccoli -> Broccoli
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Potato -> Potato
# Pumpkin -> Pumpkin
# Cauliflower -> Cauliflower
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Bean -> Bean
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Brinjal -> Brinjal
# Carrot -> Carrot
# Radish -> Radish
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Bean -> Bean
# Potato -> Potato
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Potato -> Potato
# Cabbage -> Cucumber ✘
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Bean -> Bean
# Broccoli -> Broccoli
# Tomato -> Tomato
# Brinjal -> Brinjal
# Papaya -> Papaya
# Carrot -> Carrot
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Papaya -> Papaya
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Radish -> Radish
# Brinjal -> Brinjal
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Papaya -> Papaya
# Potato -> Potato
# Broccoli -> Broccoli
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Radish -> Radish
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Bean -> Bean
# Cabbage -> Cabbage
# Bean -> Bean
# Cauliflower -> Cauliflower
# Radish -> Radish
# Bean -> Bean
# Brinjal -> Brinjal
# Tomato -> Tomato
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Papaya -> Papaya
# Tomato -> Tomato
# Bean -> Bean
# Carrot -> Carrot
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Cauliflower -> Cauliflower
# Capsium -> Capsium
# Capsium -> Capsium
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Radish -> Radish
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Brinjal -> Brinjal
# Bean -> Bean
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Radish -> Radish
# Tomato -> Tomato
# Bean -> Bean
# Carrot -> Carrot
# Potato -> Potato
# Capsium -> Capsium
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Potato -> Potato
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Brinjal -> Brinjal
# Tomato -> Tomato
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Bean -> Bean
# Radish -> Radish
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Capsium -> Capsium
# Papaya -> Papaya
# Tomato -> Tomato
# Carrot -> Carrot
# Cucumber -> Cucumber
# Capsium -> Capsium
# Carrot -> Carrot
# Potato -> Potato
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Papaya -> Papaya
# Radish -> Radish
# Tomato -> Tomato
# Broccoli -> Broccoli
# Carrot -> Carrot
# Cucumber -> Cucumber
# Radish -> Radish
# Cabbage -> Cabbage
# Radish -> Radish
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Cauliflower -> Cauliflower
# Capsium -> Capsium
# Cucumber -> Cucumber
# Potato -> Potato
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Radish -> Radish
# Cabbage -> Cabbage
# Bean -> Bean
# Bean -> Bean
# Carrot -> Carrot
# Tomato -> Tomato
# Bean -> Bean
# Tomato -> Tomato
# Tomato -> Tomato
# Brinjal -> Brinjal
# Radish -> Radish
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Cabbage -> Cabbage
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Brinjal -> Brinjal
# Papaya -> Papaya
# Tomato -> Tomato
# Bean -> Bean
# Carrot -> Carrot
# Broccoli -> Broccoli
# Carrot -> Carrot
# Cauliflower -> Cauliflower
# Bean -> Bean
# Papaya -> Papaya
# Radish -> Radish
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Capsium -> Capsium
# Cucumber -> Cucumber
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Cabbage -> Cabbage
# Bean -> Bean
# Potato -> Potato
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Cauliflower -> Cauliflower
# Potato -> Potato
# Radish -> Radish
# Tomato -> Tomato
# Brinjal -> Brinjal
# Bean -> Bean
# Pumpkin -> Pumpkin
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Radish -> Radish
# Papaya -> Papaya
# Brinjal -> Brinjal
# Capsium -> Capsium
# Radish -> Radish
# Tomato -> Tomato
# Bean -> Bean
# Brinjal -> Brinjal
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Potato -> Potato
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Potato -> Potato
# Tomato -> Tomato
# Potato -> Potato
# Cabbage -> Cabbage
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Bean -> Bean
# Papaya -> Papaya
# Cucumber -> Cucumber
# Radish -> Radish
# Cabbage -> Cabbage
# Radish -> Radish
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Papaya -> Papaya
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Capsium -> Capsium
# Papaya -> Papaya
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Capsium -> Capsium
# Cucumber -> Cucumber
# Carrot -> Carrot
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Potato -> Potato
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Cauliflower -> Cauliflower
# Pumpkin -> Pumpkin
# Broccoli -> Brinjal ✘
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Cucumber -> Cucumber
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Cabbage -> Tomato ✘
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Papaya -> Papaya
# Carrot -> Carrot
# Potato -> Potato
# Cucumber -> Cucumber
# Papaya -> Papaya
# Capsium -> Capsium
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Broccoli -> Broccoli
# Radish -> Radish
# Pumpkin -> Pumpkin
# Brinjal -> Brinjal
# Capsium -> Capsium
# Capsium -> Capsium
# Cabbage -> Cabbage
# Bean -> Bean
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Broccoli -> Broccoli
# Potato -> Potato
# Bean -> Bean
# Capsium -> Capsium
# Broccoli -> Broccoli
# Cabbage -> Cabbage
# Broccoli -> Broccoli
# Papaya -> Papaya
# Potato -> Potato
# Capsium -> Capsium
# Cucumber -> Cucumber
# Papaya -> Papaya
# Cabbage -> Cabbage
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Radish -> Radish
# Tomato -> Tomato
# Tomato -> Tomato
# Brinjal -> Brinjal
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Bean -> Brinjal ✘
# Carrot -> Carrot
# Potato -> Potato
# Tomato -> Tomato
# Potato -> Potato
# Potato -> Potato
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Radish -> Radish
# Papaya -> Papaya
# Radish -> Radish
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Carrot -> Carrot
# Bottle_Gourd -> Bottle_Gourd
# Bean -> Bean
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Radish -> Radish
# Potato -> Potato
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Radish -> Radish
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Papaya -> Papaya
# Capsium -> Capsium
# Bean -> Bean
# Papaya -> Papaya
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Carrot -> Carrot
# Cucumber -> Cucumber
# Carrot -> Carrot
# Capsium -> Capsium
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Cucumber -> Cucumber
# Potato -> Potato
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Cucumber -> Cucumber
# Radish -> Radish
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Bean -> Bean
# Bean -> Bean
# Tomato -> Tomato
# Brinjal -> Brinjal
# Capsium -> Capsium
# Cucumber -> Cucumber
# Capsium -> Capsium
# Carrot -> Carrot
# Brinjal -> Brinjal
# Tomato -> Tomato
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Bean -> Bean
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Cauliflower -> Bitter_Gourd ✘
# Cabbage -> Cabbage
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Bean -> Bean
# Cabbage -> Cabbage
# Bean -> Bean
# Pumpkin -> Bitter_Gourd ✘
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Potato -> Potato
# Brinjal -> Brinjal
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Broccoli -> Broccoli
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Tomato -> Tomato
# Cabbage -> Cabbage
# Cauliflower -> Cauliflower
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Tomato -> Tomato
# Cabbage -> Cabbage
# Capsium -> Capsium
# Capsium -> Capsium
# Radish -> Radish
# Potato -> Potato
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Papaya -> Papaya
# Tomato -> Tomato
# Bitter_Gourd -> Bitter_Gourd
# Pumpkin -> Pumpkin
# Potato -> Potato
# Capsium -> Capsium
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Radish -> Radish
# Papaya -> Papaya
# Carrot -> Carrot
# Tomato -> Tomato
# Potato -> Potato
# Cabbage -> Cabbage
# Papaya -> Papaya
# Tomato -> Tomato
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Brinjal -> Brinjal
# Capsium -> Capsium
# Potato -> Potato
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Bean -> Bean
# Tomato -> Tomato
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Broccoli -> Broccoli
# Cabbage -> Cabbage
# Papaya -> Papaya
# Brinjal -> Brinjal
# Cucumber -> Cucumber
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Radish -> Radish
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Tomato -> Tomato
# Cucumber -> Cucumber
# Papaya -> Papaya
# Papaya -> Papaya
# Potato -> Potato
# Capsium -> Capsium
# Brinjal -> Brinjal
# Papaya -> Papaya
# Tomato -> Tomato
# Bean -> Bean
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Bean -> Bean
# Cabbage -> Cabbage
# Papaya -> Papaya
# Capsium -> Capsium
# Tomato -> Tomato
# Carrot -> Carrot
# Capsium -> Capsium
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Cucumber -> Cucumber
# Potato -> Potato
# Cucumber -> Cucumber
# Tomato -> Tomato
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Radish -> Radish
# Cucumber -> Bean ✘
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Bean -> Bean
# Capsium -> Capsium
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Bean -> Bean
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Brinjal -> Brinjal
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Tomato -> Tomato
# Potato -> Potato
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Radish -> Radish
# Potato -> Potato
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Radish -> Radish
# Bean -> Bean
# Radish -> Radish
# Capsium -> Capsium
# Bean -> Bean
# Broccoli -> Broccoli
# Radish -> Radish
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Broccoli -> Broccoli
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Radish -> Radish
# Tomato -> Tomato
# Broccoli -> Broccoli
# Papaya -> Papaya
# Bitter_Gourd -> Bitter_Gourd
# Cucumber -> Cucumber
# Potato -> Potato
# Tomato -> Tomato
# Cabbage -> Cabbage
# Carrot -> Carrot
# Papaya -> Papaya
# Cucumber -> Cucumber
# Capsium -> Capsium
# Cucumber -> Cucumber
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Brinjal -> Brinjal
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Tomato -> Tomato
# Carrot -> Carrot
# Bean -> Bean
# Pumpkin -> Pumpkin
# Cabbage -> Broccoli ✘
# Capsium -> Capsium
# Broccoli -> Broccoli
# Radish -> Radish
# Cabbage -> Cabbage
# Tomato -> Tomato
# Bitter_Gourd -> Bitter_Gourd
# Tomato -> Tomato
# Papaya -> Papaya
# Cabbage -> Cabbage
# Tomato -> Tomato
# Cabbage -> Cabbage
# Potato -> Potato
# Radish -> Radish
# Papaya -> Papaya
# Cabbage -> Cabbage
# Radish -> Radish
# Capsium -> Capsium
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Radish -> Tomato ✘
# Radish -> Tomato ✘
# Broccoli -> Broccoli
# Radish -> Radish
# Capsium -> Capsium
# Papaya -> Papaya
# Broccoli -> Broccoli
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Potato -> Potato
# Radish -> Radish
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Bean -> Bean
# Bean -> Bean
# Broccoli -> Broccoli
# Capsium -> Capsium
# Bean -> Bean
# Potato -> Potato
# Bean -> Bean
# Pumpkin -> Pumpkin
# Radish -> Radish
# Carrot -> Carrot
# Bean -> Bean
# Brinjal -> Brinjal
# Radish -> Radish
# Carrot -> Carrot
# Broccoli -> Broccoli
# Papaya -> Papaya
# Radish -> Radish
# Cucumber -> Cucumber
# Radish -> Radish
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Broccoli -> Broccoli
# Cauliflower -> Cauliflower
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Carrot -> Carrot
# Capsium -> Capsium
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Cabbage -> Cabbage
# Carrot -> Carrot
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Cucumber -> Cucumber
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Carrot -> Carrot
# Tomato -> Tomato
# Radish -> Radish
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Brinjal -> Brinjal
# Papaya -> Papaya
# Brinjal -> Brinjal
# Bean -> Bean
# Bean -> Bean
# Capsium -> Capsium
# Capsium -> Capsium
# Capsium -> Capsium
# Radish -> Radish
# Cauliflower -> Cauliflower
# Broccoli -> Broccoli
# Cucumber -> Brinjal ✘
# Radish -> Radish
# Bean -> Bean
# Broccoli -> Broccoli
# Bean -> Bean
# Papaya -> Papaya
# Cabbage -> Tomato ✘
# Pumpkin -> Pumpkin
# Radish -> Radish
# Cucumber -> Cucumber
# Carrot -> Carrot
# Potato -> Potato
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Bean -> Bean
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Carrot -> Carrot
# Tomato -> Tomato
# Bean -> Bean
# Cucumber -> Cucumber
# Tomato -> Tomato
# Tomato -> Tomato
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Cabbage -> Cabbage
# Bottle_Gourd -> Cucumber ✘
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Bean -> Bean
# Potato -> Potato
# Capsium -> Capsium
# Radish -> Radish
# Capsium -> Capsium
# Tomato -> Papaya ✘
# Carrot -> Carrot
# Capsium -> Capsium
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Cauliflower -> Cauliflower
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Tomato -> Tomato
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Capsium -> Capsium
# Tomato -> Tomato
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Radish -> Radish
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Carrot -> Carrot
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Brinjal -> Brinjal
# Carrot -> Carrot
# Bean -> Bean
# Pumpkin -> Pumpkin
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Bean -> Bean
# Capsium -> Capsium
# Cauliflower -> Cauliflower
# Bean -> Bean
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Radish -> Radish
# Potato -> Potato
# Cauliflower -> Cauliflower
# Cabbage -> Cabbage
# Cauliflower -> Cauliflower
# Capsium -> Capsium
# Carrot -> Carrot
# Broccoli -> Broccoli
# Tomato -> Tomato
# Cucumber -> Cucumber
# Carrot -> Carrot
# Cabbage -> Cabbage
# Papaya -> Papaya
# Tomato -> Tomato
# Cucumber -> Cucumber
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Bean -> Bean
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Broccoli -> Broccoli
# Papaya -> Papaya
# Bean -> Bean
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Brinjal -> Brinjal
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Radish -> Radish
# Cabbage -> Cabbage
# Capsium -> Capsium
# Carrot -> Carrot
# Bean -> Bean
# Cabbage -> Tomato ✘
# Cauliflower -> Cauliflower
# Capsium -> Capsium
# Tomato -> Tomato
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Papaya -> Papaya
# Broccoli -> Broccoli
# Bean -> Bean
# Pumpkin -> Pumpkin
# Bean -> Broccoli ✘
# Cabbage -> Cabbage
# Radish -> Radish
# Brinjal -> Brinjal
# Radish -> Potato ✘
# Radish -> Radish
# Cabbage -> Cabbage
# Potato -> Potato
# Capsium -> Capsium
# Cabbage -> Cabbage
# Potato -> Potato
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Potato -> Potato
# Cabbage -> Cabbage
# Radish -> Radish
# Papaya -> Papaya
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Carrot -> Carrot
# Bottle_Gourd -> Bottle_Gourd
# Bean -> Bean
# Cauliflower -> Cauliflower
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Carrot -> Carrot
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Carrot -> Carrot
# Pumpkin -> Pumpkin
# Potato -> Potato
# Potato -> Potato
# Bean -> Bean
# Carrot -> Carrot
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Capsium -> Capsium
# Capsium -> Capsium
# Potato -> Potato
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Cauliflower -> Cauliflower
# Radish -> Radish
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Potato -> Potato
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Carrot -> Carrot
# Tomato -> Tomato
# Carrot -> Carrot
# Papaya -> Papaya
# Broccoli -> Broccoli
# Cabbage -> Cabbage
# Potato -> Potato
# Bean -> Bean
# Broccoli -> Broccoli
# Radish -> Radish
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Papaya -> Papaya
# Broccoli -> Broccoli
# Carrot -> Carrot
# Carrot -> Carrot
# Bottle_Gourd -> Cucumber ✘
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Bean -> Bean
# Potato -> Potato
# Papaya -> Papaya
# Carrot -> Carrot
# Papaya -> Papaya
# Tomato -> Tomato
# Bean -> Bean
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Tomato -> Tomato
# Tomato -> Tomato
# Capsium -> Capsium
# Papaya -> Papaya
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Cucumber -> Cucumber
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Bean -> Capsium ✘
# Radish -> Radish
# Papaya -> Papaya
# Papaya -> Papaya
# Cabbage -> Cabbage
# Bean -> Bean
# Broccoli -> Broccoli
# Carrot -> Carrot
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Radish -> Radish
# Brinjal -> Tomato ✘
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Capsium -> Capsium
# Papaya -> Papaya
# Broccoli -> Broccoli
# Broccoli -> Pumpkin ✘
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Radish -> Radish
# Capsium -> Capsium
# Papaya -> Papaya
# Capsium -> Capsium
# Potato -> Potato
# Cabbage -> Cabbage
# Pumpkin -> Pumpkin
# Brinjal -> Brinjal
# Cauliflower -> Cauliflower
# Cabbage -> Cabbage
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Cabbage -> Cabbage
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Cucumber -> Cucumber
# Pumpkin -> Cabbage ✘
# Radish -> Radish
# Cabbage -> Cabbage
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Radish -> Radish
# Tomato -> Tomato
# Cauliflower -> Cauliflower
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Tomato -> Tomato
# Bean -> Bean
# Cauliflower -> Cauliflower
# Bean -> Bean
# Bean -> Bean
# Cabbage -> Cabbage
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Radish -> Radish
# Cauliflower -> Cauliflower
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Bean -> Bean
# Radish -> Radish
# Brinjal -> Brinjal
# Papaya -> Papaya
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Cucumber -> Cucumber
# Cucumber -> Cucumber
# Cucumber -> Cucumber
# Papaya -> Papaya
# Tomato -> Tomato
# Papaya -> Papaya
# Radish -> Radish
# Cabbage -> Cabbage
# Capsium -> Capsium
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Tomato -> Tomato
# Capsium -> Capsium
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Potato -> Potato
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Bean -> Bean
# Tomato -> Tomato
# Papaya -> Papaya
# Carrot -> Carrot
# Radish -> Radish
# Cucumber -> Cucumber
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Potato -> Potato
# Pumpkin -> Pumpkin
# Papaya -> Cucumber ✘
# Bean -> Bean
# Radish -> Radish
# Bean -> Bean
# Cucumber -> Cucumber
# Cucumber -> Cucumber
# Cucumber -> Cucumber
# Potato -> Potato
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Carrot -> Carrot
# Brinjal -> Brinjal
# Radish -> Radish
# Tomato -> Tomato
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Potato -> Potato
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Carrot -> Carrot
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Potato -> Potato
# Bean -> Bean
# Radish -> Radish
# Tomato -> Tomato
# Potato -> Potato
# Potato -> Potato
# Capsium -> Capsium
# Broccoli -> Broccoli
# Papaya -> Papaya
# Papaya -> Papaya
# Cucumber -> Cucumber
# Capsium -> Capsium
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Brinjal -> Brinjal
# Tomato -> Tomato
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Radish -> Radish
# Cabbage -> Cabbage
# Cauliflower -> Cauliflower
# Capsium -> Capsium
# Capsium -> Capsium
# Carrot -> Carrot
# Cucumber -> Cucumber
# Tomato -> Tomato
# Cabbage -> Cabbage
# Tomato -> Tomato
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Pumpkin -> Pumpkin
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Potato -> Potato
# Carrot -> Carrot
# Cabbage -> Cabbage
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Papaya -> Papaya
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Papaya -> Papaya
# Bean -> Bean
# Bean -> Bean
# Capsium -> Capsium
# Papaya -> Papaya
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Cauliflower -> Cauliflower
# Radish -> Radish
# Cauliflower -> Cauliflower
# Papaya -> Papaya
# Potato -> Potato
# Broccoli -> Broccoli
# Radish -> Radish
# Bean -> Bean
# Bitter_Gourd -> Bitter_Gourd
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Cauliflower -> Cauliflower
# Bean -> Bean
# Cucumber -> Cucumber
# Papaya -> Papaya
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Potato -> Potato
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Papaya -> Papaya
# Radish -> Radish
# Bean -> Bean
# Potato -> Potato
# Cucumber -> Cucumber
# Potato -> Potato
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Bean -> Bean
# Bean -> Bean
# Cabbage -> Cabbage
# Papaya -> Papaya
# Brinjal -> Brinjal
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Radish -> Radish
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Capsium -> Capsium
# Broccoli -> Broccoli
# Bitter_Gourd -> Bitter_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Potato -> Potato
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Carrot -> Carrot
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Brinjal -> Brinjal
# Potato -> Potato
# Bottle_Gourd -> Bottle_Gourd
# Carrot -> Carrot
# Bean -> Bean
# Carrot -> Carrot
# Tomato -> Tomato
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Radish -> Radish
# Tomato -> Tomato
# Potato -> Potato
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Capsium -> Capsium
# Capsium -> Capsium
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Carrot -> Carrot
# Papaya -> Papaya
# Papaya -> Papaya
# Carrot -> Carrot
# Bean -> Bean
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Papaya -> Papaya
# Potato -> Potato
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Cauliflower -> Cauliflower
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Carrot -> Carrot
# Tomato -> Tomato
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Potato -> Potato
# Bottle_Gourd -> Bottle_Gourd
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Potato -> Potato
# Cabbage -> Cabbage
# Capsium -> Capsium
# Bean -> Bean
# Bean -> Bean
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Brinjal -> Brinjal
# Capsium -> Capsium
# Tomato -> Tomato
# Cauliflower -> Cauliflower
# Radish -> Radish
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Potato -> Potato
# Broccoli -> Broccoli
# Cauliflower -> Cauliflower
# Radish -> Radish
# Cucumber -> Cucumber
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Broccoli -> Broccoli
# Bean -> Bean
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Bean -> Bean
# Cucumber -> Cucumber
# Capsium -> Capsium
# Papaya -> Papaya
# Broccoli -> Broccoli
# Carrot -> Carrot
# Cabbage -> Cabbage
# Carrot -> Carrot
# Cucumber -> Cucumber
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Carrot -> Carrot
# Potato -> Potato
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Potato -> Potato
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Brinjal -> Brinjal
# Bitter_Gourd -> Bitter_Gourd
# Tomato -> Tomato
# Tomato -> Tomato
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Carrot -> Carrot
# Potato -> Potato
# Cabbage -> Cabbage
# Cabbage -> Cabbage
# Pumpkin -> Broccoli ✘
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Tomato -> Tomato
# Pumpkin -> Pumpkin
# Bean -> Bean
# Papaya -> Papaya
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Papaya -> Papaya
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Bean -> Bean
# Potato -> Potato
# Bottle_Gourd -> Bottle_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Cauliflower -> Cauliflower
# Cabbage -> Cabbage
# Bean -> Bean
# Tomato -> Tomato
# Radish -> Radish
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Cabbage -> Cabbage
# Capsium -> Capsium
# Bean -> Bean
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Capsium -> Capsium
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Pumpkin -> Pumpkin
# Carrot -> Carrot
# Bean -> Bean
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Broccoli -> Broccoli
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Radish -> Radish
# Papaya -> Papaya
# Radish -> Radish
# Broccoli -> Broccoli
# Cabbage -> Cabbage
# Potato -> Potato
# Bean -> Bean
# Capsium -> Capsium
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Pumpkin -> Pumpkin
# Brinjal -> Brinjal
# Bean -> Bean
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Carrot -> Carrot
# Papaya -> Papaya
# Radish -> Radish
# Papaya -> Brinjal ✘
# Cabbage -> Cabbage
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Tomato -> Tomato
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Brinjal -> Brinjal
# Cabbage -> Cabbage
# Capsium -> Capsium
# Broccoli -> Broccoli
# Carrot -> Carrot
# Papaya -> Papaya
# Tomato -> Tomato
# Bean -> Bean
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Potato -> Potato
# Pumpkin -> Pumpkin
# Potato -> Potato
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Papaya -> Papaya
# Cabbage -> Cabbage
# Radish -> Radish
# Potato -> Potato
# Potato -> Potato
# Bean -> Bean
# Pumpkin -> Pumpkin
# Bean -> Bean
# Radish -> Radish
# Potato -> Potato
# Cauliflower -> Cauliflower
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Brinjal ✘
# Papaya -> Papaya
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Cabbage -> Cabbage
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Capsium -> Capsium
# Bean -> Bean
# Cauliflower -> Cauliflower
# Cucumber -> Cucumber
# Tomato -> Tomato
# Radish -> Radish
# Bean -> Bean
# Potato -> Potato
# Papaya -> Papaya
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Cabbage -> Cabbage
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Bean -> Bean
# Cabbage -> Cabbage
# Radish -> Radish
# Bean -> Bean
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Tomato -> Tomato
# Tomato -> Tomato
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Papaya -> Papaya
# Bean -> Bean
# Carrot -> Carrot
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Cauliflower -> Cauliflower
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Potato -> Potato
# Potato -> Potato
# Tomato -> Tomato
# Tomato -> Tomato
# Papaya -> Papaya
# Capsium -> Capsium
# Broccoli -> Broccoli
# Pumpkin -> Pumpkin
# Brinjal -> Brinjal
# Broccoli -> Broccoli
# Potato -> Potato
# Cucumber -> Cucumber
# Potato -> Potato
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Bottle_Gourd -> Bottle_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Capsium -> Capsium
# Bean -> Cucumber ✘
# Carrot -> Carrot
# Tomato -> Tomato
# Cauliflower -> Cauliflower
# Capsium -> Capsium
# Tomato -> Tomato
# Potato -> Potato
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Cabbage -> Cabbage
# Bean -> Bean
# Capsium -> Capsium
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Bitter_Gourd -> Bitter_Gourd
# Brinjal -> Brinjal
# Brinjal -> Brinjal
# Cucumber -> Cucumber
# Bitter_Gourd -> Bitter_Gourd
# Capsium -> Capsium
# Cabbage -> Cabbage
# Capsium -> Capsium
# Papaya -> Papaya
# Tomato -> Tomato
# Cauliflower -> Cauliflower
# Broccoli -> Broccoli
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Brinjal -> Brinjal
# Papaya -> Papaya
# Potato -> Potato
# Cucumber -> Cucumber
# Radish -> Radish
# Bitter_Gourd -> Bitter_Gourd
# Potato -> Potato
# Capsium -> Capsium
# Carrot -> Carrot
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Tomato -> Tomato
# Bitter_Gourd -> Bitter_Gourd
# Papaya -> Papaya
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Tomato -> Tomato
# Cabbage -> Broccoli ✘
# Capsium -> Capsium
# Cucumber -> Cucumber
# Bean -> Bean
# Brinjal -> Brinjal
# Bitter_Gourd -> Bitter_Gourd
# Bean -> Bean
# Brinjal -> Brinjal
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Bottle_Gourd -> Bottle_Gourd
# Tomato -> Tomato
# Cabbage -> Cabbage
# Bitter_Gourd -> Bitter_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Bean -> Bean
# Tomato -> Tomato
# Cabbage -> Cabbage
# Radish -> Radish
# Pumpkin -> Pumpkin
# Potato -> Potato
# Papaya -> Papaya
# Radish -> Radish
# Carrot -> Carrot
# Bottle_Gourd -> Bottle_Gourd
# Carrot -> Carrot
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Cabbage -> Cabbage
# Cauliflower -> Cauliflower
# Cabbage -> Cabbage
# Cauliflower -> Cauliflower
# Potato -> Potato
# Cucumber -> Cucumber
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Bean -> Bean
# Carrot -> Carrot
# Bean -> Bean
# Cabbage -> Cabbage
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Tomato -> Papaya ✘
# Bottle_Gourd -> Bottle_Gourd
# Cucumber -> Cucumber
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Cauliflower -> Cauliflower
# Tomato -> Tomato
# Potato -> Potato
# Brinjal -> Brinjal
# Cauliflower -> Cauliflower
# Carrot -> Carrot
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Broccoli -> Broccoli
# Cucumber -> Cucumber
# Potato -> Potato
# Tomato -> Tomato
# Papaya -> Papaya
# Tomato -> Tomato
# Brinjal -> Brinjal
# Carrot -> Carrot
# Cucumber -> Cucumber
# Broccoli -> Broccoli
# Broccoli -> Broccoli
# Tomato -> Tomato
# Carrot -> Carrot
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Cabbage -> Cabbage
# Pumpkin -> Pumpkin
# Brinjal -> Brinjal
# Carrot -> Carrot
# Capsium -> Capsium
# Brinjal -> Brinjal
# Radish -> Radish
# Cabbage -> Cabbage
# Radish -> Radish
# Broccoli -> Broccoli
# Papaya -> Papaya
# Cucumber -> Cucumber
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Bean -> Bean
# Cucumber -> Cucumber
# Tomato -> Tomato
# Bean -> Bean
# Pumpkin -> Pumpkin
# Potato -> Potato
# Radish -> Radish
# Cauliflower -> Cauliflower
# Brinjal -> Brinjal
# Potato -> Potato
# Potato -> Potato
# Bean -> Bean
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Bottle_Gourd -> Cucumber ✘
# Bottle_Gourd -> Bottle_Gourd
# Radish -> Radish
# Pumpkin -> Pumpkin
# Pumpkin -> Pumpkin
# Tomato -> Tomato
# Cucumber -> Cucumber
# Carrot -> Carrot
# Cabbage -> Cabbage
# Potato -> Potato
# Bean -> Broccoli ✘
# Capsium -> Capsium
# Capsium -> Capsium
# Pumpkin -> Pumpkin
# Bottle_Gourd -> Bottle_Gourd
# Papaya -> Papaya
# Papaya -> Papaya
# Potato -> Potato
# Bitter_Gourd -> Bitter_Gourd
# Cauliflower -> Cauliflower
# Radish -> Radish
# Bottle_Gourd -> Bottle_Gourd
# Bitter_Gourd -> Bitter_Gourd
# Radish -> Radish
# Radish -> Radish
# Broccoli -> Broccoli
# Pumpkin -> Pumpkin
# Cabbage -> Cabbage
# Potato -> Potato
# Capsium -> Capsium
# Potato -> Potato
# Brinjal -> Brinjal
# Pumpkin -> Pumpkin
# Broccoli -> Broccoli
# Papaya -> Papaya
# Bitter_Gourd -> Bitter_Gourd
# Papaya -> Papaya
# Cauliflower -> Cauliflower
# Bitter_Gourd -> Bitter_Gourd
# Tomato -> Tomato
# Potato -> Potato
# Potato -> Potato
# Carrot -> Carrot
# Cucumber -> Cucumber
#
# Total de errores: 52
#
# Total de aciertos: 2948
